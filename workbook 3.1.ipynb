# %% [markdown]
# Dataset Natural History Museum
# INITIAL STEPS
# Start by implementing this instruction into CoLab

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Naming this CSV file in CoLab. This is in place in order to use "chd" instead of typing out the long address.

# %%
chd=pd.read_csv("resource.csv")
# Out:
# <ipython-input-13-23fcbec2ea1a>:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   chd=pd.read_csv("resource.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# To get the first 4 rows, type:

# %%
chd [0:4]
# Out:
#        _id  associatedMedia._id  associatedMedia.assetID  \
# 0  1420777                  NaN                      NaN
# 1  1402488                  NaN                      NaN
# 2   992286                  NaN                      NaN
# 3  1649725                  NaN                      NaN
#
#    associatedMedia.category  associatedMedia.created  associatedMedia.creator  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
#
#    associatedMedia.identifier  associatedMedia.license  associatedMedia.mime  \
# 0                         NaN                      NaN                   NaN
# 1                         NaN                      NaN                   NaN
# 2                         NaN                      NaN                   NaN
# 3                         NaN                      NaN                   NaN
#
#    associatedMedia.modified  ...        order      phylum  \
# 0                       NaN  ...      Diptera  Arthropoda
# 1                       NaN  ...  Lepidoptera  Arthropoda
# 2                       NaN  ...   Coleoptera  Arthropoda
# 3                       NaN  ...  Hymenoptera  Arthropoda
#
#                                   scientificName  specificEpithet  \
# 0  Fidena (Fidena) fulvitibialis (Ricardo, 1900)    fulvitibialis
# 1                Papilio agestor restricta Leech          agestor
# 2              Cirrhicera longifrons Bates, 1881       longifrons
# 3    Ageniella (Nemagenia) longula Cresson, 1879          longula
#
#       subfamily   subgenus    suborder     superfamily   taxonRank type
# 0           NaN     Fidena  Brachycera             NaN     Species  Yes
# 1  Papilioninae        NaN         NaN   Papilionoidea  Subspecies  NaN
# 2      Lamiinae        NaN         NaN  Chrysomeloidea     Species  Yes
# 3           NaN  Nemagenia         NaN       Vespoidea     Species  NaN
#
# [4 rows x 42 columns]

# %% [markdown]
# The chart will show
# -order -phylum -scientificName -specificEpithet -subfamily -subgenus -suborder -superfamily -taxonRank -type
# You can also get down to one category you're focusing on. This is important to narrowing down specific interests. For example, if you just want to find PHYLUMS:

# %%
chd ["phylum"][0:4]
# Out:
# 0    Arthropoda
# 1    Arthropoda
# 2    Arthropoda
# 3    Arthropoda
# Name: phylum, dtype: object

# %% [markdown]
# You can combine them making a broader search.
# Sticking with only 4 rows as results:

# %%
chd [["phylum" , "scientificName" , "specificEpithet" , "subfamily"]] [0:4] =="Columns"
# Out:
#    phylum  scientificName  specificEpithet  subfamily
# 0   False           False            False      False
# 1   False           False            False      False
# 2   False           False            False      False
# 3   False           False            False      False

# %% [markdown]
# Only finding NaN (specific column)
# This will ONLY narrow down the columns, there are many rows still:
# 0 NaN 1 NaN 2 NaN 3 NaN 4 NaN ... 824749 NaN 824750 NaN 824751 NaN 824752 NaN 824753 NaN

# %%
chd.iloc[:,3]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 62047   NaN
# 62048   NaN
# 62049   NaN
# 62050   NaN
# 62051   NaN
# Name: associatedMedia.category, Length: 62052, dtype: float64

# %% [markdown]
# This is another specific search option.
# This is important because it adds another aspect in the process of narrowing the data down and identifies the #s associated with just TR.

# %%
chd[chd["taxonRank"]== "TR"]
# Out:
# Empty DataFrame
# Columns: [_id, associatedMedia._id, associatedMedia.assetID, associatedMedia.category, associatedMedia.created, associatedMedia.creator, associatedMedia.identifier, associatedMedia.license, associatedMedia.mime, associatedMedia.modified, associatedMedia.rightsHolder, associatedMedia.title, associatedMedia.type, associatedMediaCount, british, class, created, currentScientificName, family, genus, infraspecificEpithet, kindOfMaterial, kindOfMedia, kingdom, material, materialCount, materialPrimaryTypeNumber, materialSex, materialStage, materialTypes, media, modified, order, phylum, scientificName, specificEpithet, subfamily, subgenus, suborder, superfamily, taxonRank, type]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# /content/resource.csv

# %%
Columns_subset = chd [["phylum" , "scientificName" , "specificEpithet" , "subfamily"]] [0:4] =="Columns"

# %%
Columns_subset.to_csv("Columns_subset.csv", index=False)
